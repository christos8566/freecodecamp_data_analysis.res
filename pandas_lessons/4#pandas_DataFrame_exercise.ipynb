# %% [markdown]
# <a href="https://colab.research.google.com/github/christos8566/freecodecamp_data_analysis.res/blob/main/pandas_lessons/4%23pandas_DataFrame_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **DATAFRAME EXERCISE**

# %%
# import the pandas, numpy and matplotlib.pyplot librarries as pd, np, and plt.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

print('Pandas version', pd.__version__)
print('Numpy version', np.__version__)
# Out:
# Pandas version 1.5.3
# Numpy version 1.25.2

# %% [markdown]
# # A. DataFrame creation

# %% [markdown]
# ## A1. Create an empty pandas DataFrame

# %%
df = pd.DataFrame(data = [None],
                  index = [None],
                  columns = [None])
#df = pd.DataFrame()
df
# Out:
#       None
# None  None

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## A2. Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

marvel_df = pd.DataFrame(marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ## A3. Add `columns names` in the DataFrame

# %%
marvel_df.columns = ['name', 'sex', 'first appearance']
marvel_df
# Out:
#                 name     sex  first appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ## A4. Add index names to the `marvel_df` (use the character name as index)

# %%
#marvel_df.set_index(['name'], inplace = True)
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %% [markdown]
# ## A5. Drop the name column as it's now the index

# %%
marvel_df.drop(columns = ['name'], inplace = True)
marvel_df
# Out:
#                      sex  first appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ## A6. Drop 'Namor' and 'Hank Pym' rows

# %%
marvel_df.drop(index = ['Namor', 'Hank Pym'], inplace = True)
marvel_df
# Out:
#                      sex  first appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# # B. DataFrame selection, slicing and indexation

# %% [markdown]
# ## B1. Show the first 5 elements on `marvel_df`

# %%
#marvel_df.head(5)
marvel_df.iloc[:5]
# Out:
#                   sex  first appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# ## B2. Show the last 5 elements on `marvel_df`

# %%
#marvel_df.tail()
marvel_df.iloc[-5:]
# Out:
#                    sex  first appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %% [markdown]
# ## B3. Show just the sex of the first 5 elements on `marvel_df`

# %%
marvel_df.iloc[-5:, 1].to_frame()
# Out:
#                 first appearance
# name
# Doctor Strange              1963
# Scarlet Witch               1964
# Wasp                        1963
# Black Widow                 1964
# Vision                      1968

# %% [markdown]
# ## B4. Show the first_appearance of all middle elements on `marvel_df`

# %%
#marvel_df.iloc[1:-1, -1:]
marvel_df.iloc[1:-1, -1].to_frame()
# Out:
#                   first appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %% [markdown]
# ## B5. Show the first and last elements on `marvel_df`

# %%
marvel_df.iloc[[0, -1],]
# Out:
#              sex  first appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %% [markdown]
# # C. DataFrame manipulation and operations

# %% [markdown]
# ## C1. Modify the `first_appearance` of 'Vision' to year 1964

# %%
marvel_df.loc['Vision', 'first appearance'] = 1964
#marvel_df.loc[['Vision'], 'first appearance'] = 1964

marvel_df
# Out:
#                      sex  first appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1964

# %% [markdown]
# ## C2. Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
marvel_df['years_since'] = 2024 - marvel_df['first appearance']
print(type(marvel_df['first appearance']), '\n')
print(type(marvel_df[['first appearance']]), '\n')
marvel_df
# Out:
# <class 'pandas.core.series.Series'>
#
# <class 'pandas.core.frame.DataFrame'>
#                      sex  first appearance  years_since
# name
# Spider-Man          male              1962           62
# Captain America     male              1941           83
# Wolverine           male              1974           50
# Iron Man            male              1963           61
# Thor                male              1963           61
# Thing               male              1961           63
# Mister Fantastic    male              1961           63
# Hulk                male              1962           62
# Beast               male              1963           61
# Invisible Woman   female              1961           63
# Storm             female              1975           49
# Hawkeye             male              1964           60
# Daredevil           male              1964           60
# Doctor Strange      male              1963           61
# ...

# %% [markdown]
# # D. DataFrame boolean arrays (also called masks)

# %% [markdown]
# ## D1. Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
mask = marvel_df['sex'] == 'female'
#marvel_df.loc[mask]
mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %% [markdown]
# ## D2. Given the `marvel_df` pandas DataFrame, get the male characters

# %%
#marvel_df.loc[marvel_df['sex'] == 'male']
mask = marvel_df['sex'] == 'male'
mask
# Out:
# name
# Spider-Man           True
# Captain America      True
# Wolverine            True
# Iron Man             True
# Thor                 True
# Thing                True
# Mister Fantastic     True
# Hulk                 True
# Beast                True
# Invisible Woman     False
# Storm               False
# Hawkeye              True
# Daredevil            True
# Doctor Strange       True
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision               True
# Name: sex, dtype: bool

# %% [markdown]
# ## D3. Given the `marvel_df` pandas DataFrame, get the characters with first_appearance after 1970

# %%
marvel_df.loc[marvel_df['first appearance'] > 1970]
# Out:
#               sex  first appearance  years_since
# name
# Wolverine    male              1974           50
# Storm      female              1975           49

# %% [markdown]
# ## D4. Given the `marvel_df` pandas DataFrame, get the `female` characters with `first_appearance` after 1970

# %%
marvel_df.loc[(marvel_df['sex'] == 'female') & (marvel_df['first appearance'] > 1970)]
# Out:
#           sex  first appearance  years_since
# name
# Storm  female              1975           49

# %% [markdown]
# # E. DataFrame summary statistics

# %% [markdown]
# ## E1. Show basic statistics of `marvel_df`

# %%
marvel_df.describe().round(2)
# Out:
#        first appearance  years_since
# count             18.00        18.00
# mean            1962.89        61.11
# std                6.72         6.72
# min             1941.00        49.00
# 25%             1962.00        60.00
# 50%             1963.00        61.00
# 75%             1964.00        62.00
# max             1975.00        83.00

# %%
marvel_df.median()
# Out:
# <ipython-input-78-5c124dbe187a>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   marvel_df.median()
# first appearance    1963.0
# years_since           61.0
# dtype: float64

# %% [markdown]
# ## E2. Given the marvel_df pandas DataFrame, show the mean value of first_appearance

# %%
marvel_df.mean().round(2)
# Out:
# <ipython-input-80-ec04c0acf5d0>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   marvel_df.mean().round(2)
# first appearance    1962.89
# years_since           61.11
# dtype: float64

# %% [markdown]
# ## E3. Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
marvel_df['first appearance'].min()
# Out:
# 1941

# %% [markdown]
# ## E4. Given the `marvel_df` pandas DataFrame, `get` the characters with the `min` value of `first_appearance`

# %%
marvel_df.loc[marvel_df['first appearance'] == marvel_df['first appearance'].min()]
# Out:
#                   sex  first appearance  years_since
# name
# Captain America  male              1941           83

# %% [markdown]
# # F. DataFrame basic plottings

# %% [markdown]
# ## F1. Reset index names of `marvel_df`

# %%
marvel_df.reset_index(inplace = True)
marvel_df
# Out:
#                 name     sex  first appearance  years_since
# 0         Spider-Man    male              1962           62
# 1    Captain America    male              1941           83
# 2          Wolverine    male              1974           50
# 3           Iron Man    male              1963           61
# 4               Thor    male              1963           61
# 5              Thing    male              1961           63
# 6   Mister Fantastic    male              1961           63
# 7               Hulk    male              1962           62
# 8              Beast    male              1963           61
# 9    Invisible Woman  female              1961           63
# 10             Storm  female              1975           49
# 11           Hawkeye    male              1964           60
# 12         Daredevil    male              1964           60
# 13    Doctor Strange    male              1963           61
# 14     Scarlet Witch  female              1964           60
# ...

# %% [markdown]
# ## F2. Plot the values of first_appearance

# %%
marvel_df['first appearance'].plot(kind = 'line', figsize = [14, 6])
# Out:
# <Axes: >

# %% [markdown]
# ## F3. Plot a histogram (plot.hist) with values of first_appearance

# %%
marvel_df['first appearance'].plot(kind = 'hist', figsize = [12, 5])
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(marvel_df['first appearance'])
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3., 12.,  0.,  0.,  2.]),
#  array([1941. , 1944.4, 1947.8, 1951.2, 1954.6, 1958. , 1961.4, 1964.8,
#         1968.2, 1971.6, 1975. ]),
#  <BarContainer object of 10 artists>)
